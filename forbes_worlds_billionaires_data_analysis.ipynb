# %%
import pandas as pd

# %%
df = pd.read_csv("forbes_worlds_billionaires_list.csv")

# %%
df.head()
# Out:
#    Rank                     Names  Age         Worth          Work Industry  \
# 0     1                 Elon Musk   50  219000000000             Automotive
# 1     2                Jeff Bezos   58  171000000000             Technology
# 2     3  Bernard Arnault & family   73  158000000000       Fashion & Retail
# 3     4                Bill Gates   66  129000000000             Technology
# 4     5            Warren Buffett   91  118000000000  Finance & Investments
#
#          Company Name        Country         State     City  \
# 0       Tesla, SpaceX  United States         Texas   Austin
# 1              Amazon  United States    Washington  Seattle
# 2                LVMH         France  Not provided    Paris
# 3           Microsoft  United States    Washington   Medina
# 4  Berkshire Hathaway  United States      Nebraska    Omaha
#
#   Country of Citizenship                      Organization  Self Made Gender  \
# ...

# %%
df.shape
# Out:
# (2668, 18)

# %%
df.columns
# Out:
# Index(['Rank', 'Names', 'Age', 'Worth', 'Work Industry', 'Company Name',
#        'Country', 'State', 'City', 'Country of Citizenship', 'Organization',
#        'Self Made', 'Gender', 'Date of Birth', 'Title', 'Biography', 'About',
#        'Age Group'],
#       dtype='object')

# %%
df = df.rename(columns = {
    "Rank" : "Sıra" , "Names" : "İsim" , "Age" : "Yaş" , "Worth" : "Servet" ,
    "Work Industry" : "Kategori" , "Country" : "Ülke" , "Gender" : "Cinsiyet"
})

# %%
df.head()
# Out:
#    Sıra                      İsim  Yaş        Servet               Kategori  \
# 0     1                 Elon Musk   50  219000000000             Automotive
# 1     2                Jeff Bezos   58  171000000000             Technology
# 2     3  Bernard Arnault & family   73  158000000000       Fashion & Retail
# 3     4                Bill Gates   66  129000000000             Technology
# 4     5            Warren Buffett   91  118000000000  Finance & Investments
#
#          Company Name           Ülke         State     City  \
# 0       Tesla, SpaceX  United States         Texas   Austin
# 1              Amazon  United States    Washington  Seattle
# 2                LVMH         France  Not provided    Paris
# 3           Microsoft  United States    Washington   Medina
# 4  Berkshire Hathaway  United States      Nebraska    Omaha
#
#   Country of Citizenship                      Organization  Self Made  \
# 0          United States                             Tesla       True
# ...

# %%
df = df.loc[ : , ["Sıra" , "İsim" , "Yaş" , "Servet" , "Kategori" , "Ülke" , "Cinsiyet"]]

# %%
df.head()
# Out:
#    Sıra                      İsim  Yaş        Servet               Kategori  \
# 0     1                 Elon Musk   50  219000000000             Automotive
# 1     2                Jeff Bezos   58  171000000000             Technology
# 2     3  Bernard Arnault & family   73  158000000000       Fashion & Retail
# 3     4                Bill Gates   66  129000000000             Technology
# 4     5            Warren Buffett   91  118000000000  Finance & Investments
#
#             Ülke Cinsiyet
# 0  United States     Male
# 1  United States     Male
# 2         France     Male
# 3  United States     Male
# 4  United States     Male

# %%
df = df.set_index("Sıra")

# %%
df.head()
# Out:
#                           İsim  Yaş        Servet               Kategori  \
# Sıra
# 1                    Elon Musk   50  219000000000             Automotive
# 2                   Jeff Bezos   58  171000000000             Technology
# 3     Bernard Arnault & family   73  158000000000       Fashion & Retail
# 4                   Bill Gates   66  129000000000             Technology
# 5               Warren Buffett   91  118000000000  Finance & Investments
#
#                Ülke Cinsiyet
# Sıra
# 1     United States     Male
# 2     United States     Male
# 3            France     Male
# 4     United States     Male
# 5     United States     Male

# %%
df.dtypes
# Out:
# İsim        object
# Yaş          int64
# Servet       int64
# Kategori    object
# Ülke        object
# Cinsiyet    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# İsim        0
# Yaş         0
# Servet      0
# Kategori    0
# Ülke        0
# Cinsiyet    0
# dtype: int64

# %%
df.dropna(inplace=True )

# %%
df["Cinsiyet"].value_counts()
# Out:
# Cinsiyet
# Male            2341
# Female           311
# Not provided      16
# Name: count, dtype: int64

# %%
df["Cinsiyet"].value_counts(normalize = True)
# Out:
# Cinsiyet
# Male            0.877436
# Female          0.116567
# Not provided    0.005997
# Name: proportion, dtype: float64

# %%
df.iloc[150:200]
# Out:
#                                  İsim  Yaş       Servet  \
# Sıra
# 151   Ricardo Salinas Pliego & family   66  12400000000
# 152                      Jim Pattison   93  12200000000
# 152                    Charles Schwab   84  12200000000
# 154                   Goh Cheng Liang   94  12100000000
# 154              Lin Jianhua & family   59  12100000000
# 156         Charoen Sirivadhanabhakdi   77  12000000000
# 156                         Jeff Yass   63  12000000000
# 158                   John Fredriksen   77  11900000000
# 158      Andreas Struengmann & family   72  11900000000
# 158       Thomas Struengmann & family   72  11900000000
# 161                   Mikhail Fridman   57  11800000000
# 161                 Sarath Ratanavadi   56  11800000000
# 163                       Robert Kuok   98  11700000000
# 163                           Lei Jun   52  11700000000
# 163                    Zhang Congyuan   74  11700000000
# 166                       Lui Che Woo   93  11600000000
# ...

# %%
import numpy as np

# %%
missing_value = ["Not provided" , np.nan]
df = pd.read_csv("forbes_worlds_billionaires_list.csv" , na_values=missing_value)

# %%
df.isnull().sum()
# Out:
# Rank                         0
# Names                        0
# Age                          0
# Worth                        0
# Work Industry                0
# Company Name                 0
# Country                     13
# State                     1920
# City                        44
# Country of Citizenship       0
# Organization              2316
# Self Made                    0
# Gender                      16
# Date of Birth               99
# Title                        0
# Biography                    0
# About                     1106
# Age Group                    0
# dtype: int64

# %%
df = df.rename(columns = {
    "Rank" : "Sıra" , "Names" : "İsim" , "Age" : "Yaş" , "Worth" : "Servet" ,
    "Work Industry" : "Kategori" , "Country" : "Ülke" , "Gender" : "Cinsiyet"
})

# %%
df = df.loc[ : , ["Sıra" , "İsim" , "Yaş" , "Servet" , "Kategori" , "Ülke" , "Cinsiyet"]]

# %%
df.head()
# Out:
#    Sıra                      İsim  Yaş        Servet               Kategori  \
# 0     1                 Elon Musk   50  219000000000             Automotive
# 1     2                Jeff Bezos   58  171000000000             Technology
# 2     3  Bernard Arnault & family   73  158000000000       Fashion & Retail
# 3     4                Bill Gates   66  129000000000             Technology
# 4     5            Warren Buffett   91  118000000000  Finance & Investments
#
#             Ülke Cinsiyet
# 0  United States     Male
# 1  United States     Male
# 2         France     Male
# 3  United States     Male
# 4  United States     Male

# %%
df.dtypes
# Out:
# Sıra         int64
# İsim        object
# Yaş          int64
# Servet       int64
# Kategori    object
# Ülke        object
# Cinsiyet    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sıra         0
# İsim         0
# Yaş          0
# Servet       0
# Kategori     0
# Ülke        13
# Cinsiyet    16
# dtype: int64

# %%
df = df.dropna(inplace = True)

# %%
df = pd.read_csv("forbes_worlds_billionaires_list.csv")

# %%
df = df.rename(columns = {
    "Rank" : "Sıra" , "Names" : "İsim" , "Age" : "Yaş" , "Worth" : "Servet" ,
    "Work Industry" : "Kategori" , "Country" : "Ülke" , "Gender" : "Cinsiyet"
})

# %%
df = df.loc[ : , ["Sıra" , "İsim" , "Yaş" , "Servet" , "Kategori" , "Ülke" , "Cinsiyet"]]

# %%
df.shape
# Out:
# (2668, 7)

# %%
df = df.set_index("Sıra")

# %%
df.head()
# Out:
#                           İsim  Yaş        Servet               Kategori  \
# Sıra
# 1                    Elon Musk   50  219000000000             Automotive
# 2                   Jeff Bezos   58  171000000000             Technology
# 3     Bernard Arnault & family   73  158000000000       Fashion & Retail
# 4                   Bill Gates   66  129000000000             Technology
# 5               Warren Buffett   91  118000000000  Finance & Investments
#
#                Ülke Cinsiyet
# Sıra
# 1     United States     Male
# 2     United States     Male
# 3            France     Male
# 4     United States     Male
# 5     United States     Male

# %%
df.dtypes
# Out:
# İsim        object
# Yaş          int64
# Servet       int64
# Kategori    object
# Ülke        object
# Cinsiyet    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# İsim        0
# Yaş         0
# Servet      0
# Kategori    0
# Ülke        0
# Cinsiyet    0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (2668, 6)

# %%
df["Cinsiyet"].value_counts()
# Out:
# Cinsiyet
# Male            2341
# Female           311
# Not provided      16
# Name: count, dtype: int64

# %%
df["Cinsiyet"].value_counts(normalize = True)
# Out:
# Cinsiyet
# Male            0.877436
# Female          0.116567
# Not provided    0.005997
# Name: proportion, dtype: float64

# %%
df[df["Ülke"] == "Turkey"].Cinsiyet.value_counts(normalize = True)
# Out:
# Cinsiyet
# Male      0.826087
# Female    0.173913
# Name: proportion, dtype: float64

# %%
df["Ülke"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Not provided', 'Chile', 'Russia',
#        'Sweden', 'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria',
#        'Denmark', 'Thailand', 'Malaysia', 'Brazil', 'Colombia',
#        'New Zealand', 'South Korea', 'South Africa', 'Philippines',
#        'Egypt', 'Taiwan', 'Israel', 'Vietnam', 'Poland', 'Norway',
#        'Cayman Islands', 'Netherlands', 'Eswatini (Swaziland)', 'Peru',
#        'Algeria', 'Kazakhstan', 'Georgia', 'Portugal',
#        'British Virgin Islands', 'Turkey', 'Finland', 'Ukraine',
#        'Argentina', 'Ireland', 'Bermuda', 'Lebanon', 'Cambodia', 'Oman',
#        'Guernsey', 'Liechtenstein', 'Turks and Caicos Islands', 'Qatar',
#        'Morocco', 'Uruguay', 'Slovakia', 'Romania', 'Nepal', 'Tanzania',
# ...

# %%
df[df["Ülke"] == "Canada"].Cinsiyet.value_counts(normalize = True)
# Out:
# Cinsiyet
# Male      0.933333
# Female    0.066667
# Name: proportion, dtype: float64

# %%
df_cinsiyet = df.groupby(["Cinsiyet"])

# %%
df_cinsiyet["Yaş"].mean()
# Out:
# Cinsiyet
# Female          62.88746
# Male            64.38317
# Not provided    63.56250
# Name: Yaş, dtype: float64

# %%
import seaborn as sns
sns.set_theme()
sns.set(rc = {"figure.dpi" : 300})
import warnings
warnings.filterwarnings("ignore")

# %%
df_cinsiyet.size()
# Out:
# Cinsiyet
# Female           311
# Male            2341
# Not provided      16
# dtype: int64

# %%
df_cinsiyet.size().plot(kind = "bar")
# Out:
# <Axes: xlabel='Cinsiyet'>

# %%
sns.barplot(y = df["İsim"][:10] , x = df["Servet"][:10])
# Out:
# <Axes: xlabel='Servet', ylabel='İsim'>

# %%
len(df["Ülke"])
# Out:
# 2668

# %%
len(df["Ülke"].unique())
# Out:
# 74

# %%
df_ülke = df.groupby("Ülke")

# %%
df_ülke_sayi = pd.DataFrame(df_ülke.size().sort_values(ascending = False), columns = ["Sayi"])

# %%
df_ülke_sayi.head()
# Out:
#                 Sayi
# Ülke
# United States    748
# China            571
# India            159
# Germany          112
# United Kingdom    85

# %%
sns.barplot(x = df_ülke_sayi["Sayi"][: 10] , y = df_ülke_sayi.index[:10] )
# Out:
# <Axes: xlabel='Sayi', ylabel='Ülke'>

# %%
df_türkiye = df[df["Ülke"]== "Turkey"]

# %%
df_türkiye["İsim"].count()
# Out:
# 23

# %%
df_türkiye.head(10)
# Out:
#                      İsim  Yaş      Servet                    Kategori  \
# Sıra
# 601           Murat Ulker   63  4700000000             Food & Beverage
# 1292    Ferit Faik Sahenk   58  2400000000                 Diversified
# 1341         Erman Ilicak   54  2300000000  Construction & Engineering
# 1397         Filiz Sahenk   55  2200000000                 Diversified
# 1579       Sezai Bacaksiz   72  1900000000                 Diversified
# 1579        Nihat Ozdemir   72  1900000000                 Diversified
# 1645    Ibrahim Erdemoglu   59  1800000000               Manufacturing
# 1818  Semahat Sevim Arsel   93  1600000000                 Diversified
# 1929  Hamdi Akin & family   67  1500000000                 Diversified
# 1929          Ahmet Calik   64  1500000000                 Diversified
#
#         Ülke Cinsiyet
# Sıra
# 601   Turkey     Male
# 1292  Turkey     Male
# 1341  Turkey     Male
# 1397  Turkey   Female
# 1579  Turkey     Male
# 1579  Turkey     Male
# ...

# %%
  sns.barplot(y = df_türkiye["İsim"][:10] , x = df_türkiye["Servet"][:10])
# Out:
# <Axes: xlabel='Servet', ylabel='İsim'>

# %%
df["Kategori"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion & Retail',
#        'Finance & Investments', 'Diversified', 'Media & Entertainment',
#        'Telecom', 'Food & Beverage', 'Logistics', 'Real Estate',
#        'Metals & Mining', 'Manufacturing', 'Gambling & Casinos',
#        'Healthcare', 'Service', 'Energy', 'Construction & Engineering',
#        'Sports'], dtype=object)

# %%
df["Kategori"] = df["Kategori"].apply(lambda x:x.replace(" " , "")).apply(lambda x:x.replace("&" , "_"))

# %%
df["Kategori"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion_Retail',
#        'Finance_Investments', 'Diversified', 'Media_Entertainment',
#        'Telecom', 'Food_Beverage', 'Logistics', 'RealEstate',
#        'Metals_Mining', 'Manufacturing', 'Gambling_Casinos', 'Healthcare',
#        'Service', 'Energy', 'Construction_Engineering', 'Sports'],
#       dtype=object)

# %%
df_kategori = df.groupby("Kategori").size()

# %%
df_kategori.head()
# Out:
# Kategori
# Automotive                   70
# Construction_Engineering     46
# Diversified                 180
# Energy                       95
# Fashion_Retail              250
# dtype: int64

# %%
df_kategori = df_kategori.to_frame()

# %%
df_kategori.head()
# Out:
#                             0
# Kategori
# Automotive                 70
# Construction_Engineering   46
# Diversified               180
# Energy                     95
# Fashion_Retail            250

# %%
df_kategori = df_kategori.rename(columns = {0: "Sayı"}).sort_values(by ="Sayı" , ascending = False)

# %%
df_kategori.head()
# Out:
#                      Sayı
# Kategori
# Finance_Investments   392
# Technology            343
# Manufacturing         337
# Fashion_Retail        250
# Healthcare            217

# %%
sns.barplot(x = df_kategori["Sayı"][:10] ,y =  df_kategori.index[:10])
# Out:
# <Axes: xlabel='Sayı', ylabel='Kategori'>

# %%
sns.scatterplot(x=df["Yaş"], y=df["Servet"])
# Out:
# <Axes: xlabel='Yaş', ylabel='Servet'>

# %%
sns.histplot(df["Yaş"])
# Out:
# <Axes: xlabel='Yaş', ylabel='Count'>

# %%
df_yas = df.sort_values(by="Yaş")

# %%
df_yas
# Out:
#                      İsim  Yaş       Servet             Kategori  \
# Sıra
# 1292  Kevin David Lehmann   19   2400000000       Fashion_Retail
# 2190   Alexandra Andresen   25   1300000000          Diversified
# 1929          Wang Zelong   25   1500000000        Metals_Mining
# 1929     Pedro Franceschi   25   1500000000  Finance_Investments
# 2190   Katharina Andresen   26   1300000000          Diversified
# ...                   ...  ...          ...                  ...
# 622         Masatoshi Ito   97   4600000000       Fashion_Retail
# 1238       Charles Munger   98   2500000000  Finance_Investments
# 1341        David Murdock   98   2300000000        Food_Beverage
# 163           Robert Kuok   98  11700000000          Diversified
# 1645        George Joseph  100   1800000000  Finance_Investments
#
#                Ülke Cinsiyet
# Sıra
# 1292   Not provided     Male
# 2190         Norway   Female
# 1929          China     Male
# 1929  United States     Male
# ...

# %%
sns.barplot(y = df_yas["İsim"][:10] , x = df_yas["Yaş"][:10])
# Out:
# <Axes: xlabel='Yaş', ylabel='İsim'>
